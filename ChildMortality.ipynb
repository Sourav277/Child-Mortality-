# %% [markdown]
# ## Importing Relevant Packages :

# %%
# %matplotlib inline
import pandas as pd

# %% [markdown]
# ### Reading the data

# %%
mortality_rates=pd.read_csv('mortality.csv')
mortality_rates.shape
# Out:
# (5044, 5)

# %%
mortality_rates
# Out:
#           Country  Year  \
# 0     Afghanistan  2015
# 1     Afghanistan  2014
# 2     Afghanistan  2013
# 3     Afghanistan  2012
# 4     Afghanistan  2011
# 5     Afghanistan  2010
# 6     Afghanistan  2009
# 7     Afghanistan  2008
# 8     Afghanistan  2007
# 9     Afghanistan  2006
# 10    Afghanistan  2005
# 11    Afghanistan  2004
# 12    Afghanistan  2003
# 13    Afghanistan  2002
# 14    Afghanistan  2001
# 15    Afghanistan  2000
# 16    Afghanistan  1999
# 17    Afghanistan  1998
# 18    Afghanistan  1997
# 19    Afghanistan  1996
# 20    Afghanistan  1995
# 21    Afghanistan  1994
# 22    Afghanistan  1993
# 23    Afghanistan  1992
# 24    Afghanistan  1991
# 25    Afghanistan  1990
# 26        Albania  2015
# 27        Albania  2014
# 28        Albania  2013
# 29        Albania  2012
# ...           ...   ...
# 5014       Zambia  1993
# 5015       Zambia  1992
# 5016       Zambia  1991
# 5017       Zambia  1990
# 5018     Zimbabwe  2015
# 5019     Zimbabwe  2014
# 5020     Zimbabwe  2013
# 5021     Zimbabwe  2012
# 5022     Zimbabwe  2011
# 5023     Zimbabwe  2010
# 5024     Zimbabwe  2009
# 5025     Zimbabwe  2008
# 5026     Zimbabwe  2007
# 5027     Zimbabwe  2006
# 5028     Zimbabwe  2005
# 5029     Zimbabwe  2004
# 5030     Zimbabwe  2003
# 5031     Zimbabwe  2002
# 5032     Zimbabwe  2001
# 5033     Zimbabwe  2000
# 5034     Zimbabwe  1999
# 5035     Zimbabwe  1998
# 5036     Zimbabwe  1997
# 5037     Zimbabwe  1996
# 5038     Zimbabwe  1995
# 5039     Zimbabwe  1994
# 5040     Zimbabwe  1993
# 5041     Zimbabwe  1992
# 5042     Zimbabwe  1991
# 5043     Zimbabwe  1990
#
#      Infant mortality rate (probability of dying between birth and age 1 per 1000 live births)  \
# 0                                      66.3 [52.7-83.9]
# 1                                      68.1 [55.7-83.6]
# 2                                      69.9 [58.7-83.5]
# 3                                      71.7 [61.6-83.7]
# 4                                      73.4 [64.4-84.2]
# 5                                      75.1 [66.9-85.1]
# 6                                      76.8 [69.0-86.1]
# 7                                      78.6 [71.2-87.3]
# 8                                      80.4 [73.4-88.9]
# 9                                      82.3 [75.5-90.7]
# 10                                     84.4 [77.7-92.6]
# 11                                     86.7 [79.9-94.8]
# 12                                     89.0 [82.1-97.0]
# 13                                     91.2 [84.3-99.3]
# 14                                    93.4 [86.3-101.6]
# 15                                    95.4 [88.2-103.6]
# 16                                    97.2 [89.9-105.4]
# 17                                    98.9 [91.4-107.2]
# 18                                   100.7 [92.9-109.1]
# 19                                   102.7 [94.5-111.3]
# 20                                   105.0 [96.2-114.1]
# 21                                   107.7 [98.6-117.2]
# 22                                  110.9 [101.4-120.9]
# 23                                  114.4 [104.6-125.2]
# 24                                  118.3 [108.0-129.9]
# 25                                  122.5 [111.6-135.5]
# 26                                      12.5 [7.0-22.2]
# 27                                      12.9 [7.5-22.1]
# 28                                      13.3 [7.9-22.1]
# 29                                      13.8 [8.5-22.2]
# ...                                                 ...
# 5014                                111.3 [105.4-117.4]
# 5015                                112.4 [106.5-118.5]
# 5016                                113.0 [107.1-119.3]
# 5017                                113.3 [107.4-119.5]
# 5018                                   46.6 [35.8-61.1]
# 5019                                   47.6 [37.9-60.5]
# 5020                                   48.8 [40.4-59.9]
# 5021                                   49.4 [42.5-58.6]
# 5022                                   54.0 [47.9-62.0]
# 5023                                   55.8 [50.4-62.5]
# 5024                                   57.7 [52.7-63.6]
# 5025                                   58.9 [54.2-64.3]
# 5026                                   59.9 [55.3-65.2]
# 5027                                   60.3 [55.8-65.5]
# 5028                                   61.0 [56.4-66.0]
# 5029                                   61.5 [56.8-66.6]
# 5030                                   61.9 [57.1-66.8]
# 5031                                   62.7 [57.7-67.6]
# 5032                                   63.2 [58.3-68.1]
# 5033                                   63.5 [58.8-68.4]
# 5034                                   63.5 [59.0-68.2]
# 5035                                   63.3 [58.9-67.7]
# 5036                                   62.7 [58.5-67.0]
# 5037                                   61.6 [57.6-65.8]
# 5038                                   60.1 [56.3-64.1]
# 5039                                   58.1 [54.5-62.0]
# 5040                                   56.4 [52.9-60.0]
# 5041                                   54.5 [51.0-58.0]
# 5042                                   52.6 [49.2-56.1]
# 5043                                   51.2 [47.8-54.6]
#
#      Neonatal mortality rate (per 1000 live births)  \
# 0                                  35.5 [19.2-56.4]
# 1                                  36.1 [19.5-57.5]
# 2                                  36.8 [20.1-58.6]
# 3                                  37.4 [20.4-60.0]
# 4                                  38.1 [20.7-61.0]
# 5                                  38.7 [21.1-61.9]
# 6                                  39.1 [21.6-62.5]
# 7                                  39.8 [22.2-63.0]
# 8                                  40.4 [22.5-63.6]
# 9                                  41.0 [23.1-64.6]
# 10                                 41.7 [23.7-65.3]
# 11                                 42.5 [24.2-66.3]
# 12                                 43.2 [25.0-67.2]
# 13                                 43.9 [25.4-68.2]
# 14                                 44.5 [25.9-68.7]
# 15                                 45.2 [26.3-69.2]
# 16                                 45.6 [26.8-69.9]
# 17                                 46.1 [27.3-70.6]
# 18                                 47.0 [27.8-70.9]
# 19                                 47.5 [28.2-71.6]
# 20                                 48.2 [28.9-72.1]
# 21                                 49.1 [29.8-73.0]
# 22                                 49.9 [30.5-73.9]
# 23                                 50.9 [31.4-75.3]
# 24                                 51.9 [32.3-76.3]
# 25                                 52.8 [33.4-77.7]
# 26                                   6.2 [3.1-12.9]
# 27                                   6.5 [3.3-12.9]
# 28                                   6.8 [3.5-12.9]
# 29                                   7.0 [3.7-12.9]
# ...                                             ...
# 5014                               34.6 [30.7-38.4]
# 5015                               35.1 [31.1-38.7]
# 5016                               35.7 [31.8-39.3]
# 5017                               36.2 [32.4-39.6]
# 5018                               23.5 [16.8-33.8]
# 5019                               23.9 [17.8-33.2]
# 5020                               24.4 [18.8-32.2]
# 5021                               24.8 [19.8-31.2]
# 5022                               25.1 [20.6-30.2]
# 5023                               25.3 [21.2-29.4]
# 5024                               25.2 [21.4-28.7]
# 5025                               24.8 [21.5-28.0]
# 5026                               24.3 [21.3-27.3]
# 5027                               23.7 [20.9-26.7]
# 5028                               23.1 [20.4-26.1]
# 5029                               22.6 [19.9-25.4]
# 5030                               22.2 [19.5-24.8]
# 5031                               21.8 [19.0-24.3]
# 5032                               21.4 [18.7-23.9]
# 5033                               21.0 [18.4-23.5]
# 5034                               20.7 [18.3-23.3]
# 5035                               20.6 [18.2-23.1]
# 5036                               20.5 [18.2-23.1]
# 5037                               20.4 [18.2-23.1]
# 5038                               20.3 [18.2-23.0]
# 5039                               20.4 [18.3-23.0]
# 5040                               20.5 [18.4-23.1]
# 5041                               20.8 [18.6-23.4]
# 5042                               21.3 [19.0-23.8]
# 5043                               22.0 [19.5-24.4]
#
#      Under-five mortality rate (probability of dying by age 5 per 1000 live births)
# 0                                     91.1 [69.6-118.8]
# 1                                     93.9 [74.5-118.3]
# 2                                     96.7 [79.1-118.2]
# 3                                     99.5 [83.8-118.5]
# 4                                    102.3 [88.1-119.3]
# 5                                    105.0 [92.0-120.6]
# 6                                    107.6 [95.4-122.2]
# 7                                    110.4 [98.9-124.2]
# 8                                   113.2 [102.2-126.7]
# 9                                   116.3 [105.6-129.6]
# 10                                  119.6 [109.0-132.6]
# 11                                  123.2 [112.5-136.1]
# 12                                  126.8 [115.9-139.6]
# 13                                  130.3 [119.4-143.1]
# 14                                  133.8 [122.6-146.8]
# 15                                  137.0 [125.6-150.1]
# 16                                  139.9 [128.3-153.1]
# 17                                  142.6 [130.7-155.9]
# 18                                  145.5 [133.1-159.0]
# 19                                  148.6 [135.6-162.7]
# 20                                  152.3 [138.3-167.2]
# 21                                  156.8 [142.0-172.4]
# 22                                  162.0 [146.5-178.5]
# 23                                  167.8 [151.7-185.3]
# 24                                  174.2 [157.2-192.8]
# 25                                  181.0 [163.1-201.7]
# 26                                      14.0 [7.9-24.9]
# 27                                      14.4 [8.4-24.9]
# 28                                      14.9 [8.9-24.9]
# 29                                      15.5 [9.6-25.0]
# ...                                                 ...
# 5014                                187.5 [176.2-199.2]
# 5015                                189.4 [178.1-201.0]
# 5016                                190.3 [178.9-202.2]
# 5017                                190.6 [179.3-202.4]
# 5018                                   70.7 [50.9-97.6]
# 5019                                   72.3 [54.6-96.3]
# 5020                                   74.5 [59.1-95.1]
# 5021                                   78.5 [65.2-96.2]
# 5022                                  85.6 [73.8-100.7]
# 5023                                  89.5 [79.0-102.2]
# 5024                                  92.9 [83.1-104.1]
# 5025                                  95.4 [86.2-106.0]
# 5026                                  98.0 [89.0-108.4]
# 5027                                 100.0 [91.0-110.2]
# 5028                                 101.9 [92.5-112.0]
# 5029                                 103.0 [93.4-113.4]
# 5030                                 104.0 [94.2-114.3]
# 5031                                 105.1 [95.1-115.3]
# 5032                                 105.6 [95.7-115.8]
# 5033                                 105.8 [96.3-115.8]
# 5034                                 105.2 [96.0-114.7]
# 5035                                 103.9 [95.2-113.0]
# 5036                                 102.0 [93.7-110.7]
# 5037                                  99.2 [91.3-107.5]
# 5038                                  95.5 [88.1-103.3]
# 5039                                   91.2 [84.3-98.6]
# 5040                                   87.0 [80.4-93.9]
# 5041                                   82.7 [76.3-89.3]
# 5042                                   78.8 [72.5-85.2]
# 5043                                   75.8 [69.7-82.0]
#
# [5044 rows x 5 columns]

# %%
mortality_rates.head()
# Out:
#        Country  Year  \
# 0  Afghanistan  2015
# 1  Afghanistan  2014
# 2  Afghanistan  2013
# 3  Afghanistan  2012
# 4  Afghanistan  2011
#
#   Infant mortality rate (probability of dying between birth and age 1 per 1000 live births)  \
# 0                                   66.3 [52.7-83.9]
# 1                                   68.1 [55.7-83.6]
# 2                                   69.9 [58.7-83.5]
# 3                                   71.7 [61.6-83.7]
# 4                                   73.4 [64.4-84.2]
#
#   Neonatal mortality rate (per 1000 live births)  \
# 0                               35.5 [19.2-56.4]
# 1                               36.1 [19.5-57.5]
# 2                               36.8 [20.1-58.6]
# 3                               37.4 [20.4-60.0]
# 4                               38.1 [20.7-61.0]
#
#   Under-five mortality rate (probability of dying by age 5 per 1000 live births)
# 0                                  91.1 [69.6-118.8]
# 1                                  93.9 [74.5-118.3]
# 2                                  96.7 [79.1-118.2]
# 3                                  99.5 [83.8-118.5]
# 4                                 102.3 [88.1-119.3]

# %%
mortality_rates.columns
# Out:
# Index(['Country', 'Year',
#        'Infant mortality rate (probability of dying between birth and age 1 per 1000 live births)',
#        'Neonatal mortality rate (per 1000 live births)',
#        'Under-five mortality rate (probability of dying by age 5 per 1000 live births)'],
#       dtype='object')

# %% [markdown]
#    Each row in the data represents three different indicators for a particular country in a particular year:
#
#   * Infant mortality rate (probability of dying between birth and age 1 per 1000 live births)
#
#   * Neonatal mortality rate (per 1000 live births)
#
#   * Under-five mortality rate (probability of dying by age 5 per 1000 live births)

# %% [markdown]
#  ###### Let us start with exploring if these infant mortality indicators have improved over time?
# ###### DataPreprocessing Start Here :

# %%
mortality_rates=mortality_rates[['Country','Year','Under-five mortality rate (probability of dying by age 5 per 1000 live births)']]

# the name of the last column is too long,let's keep it short

mortality_rates.rename(columns=
                      {'Under-five mortality rate (probability of dying by age 5 per 1000 live births)':
                      'under5_m_rate'},inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3778: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
mortality_rates.columns
# Out:
# Index(['Country', 'Year', 'under5_m_rate'], dtype='object')

# %%
mortality_rates
# Out:
#           Country  Year        under5_m_rate
# 0     Afghanistan  2015    91.1 [69.6-118.8]
# 1     Afghanistan  2014    93.9 [74.5-118.3]
# 2     Afghanistan  2013    96.7 [79.1-118.2]
# 3     Afghanistan  2012    99.5 [83.8-118.5]
# 4     Afghanistan  2011   102.3 [88.1-119.3]
# 5     Afghanistan  2010   105.0 [92.0-120.6]
# 6     Afghanistan  2009   107.6 [95.4-122.2]
# 7     Afghanistan  2008   110.4 [98.9-124.2]
# 8     Afghanistan  2007  113.2 [102.2-126.7]
# 9     Afghanistan  2006  116.3 [105.6-129.6]
# 10    Afghanistan  2005  119.6 [109.0-132.6]
# 11    Afghanistan  2004  123.2 [112.5-136.1]
# 12    Afghanistan  2003  126.8 [115.9-139.6]
# 13    Afghanistan  2002  130.3 [119.4-143.1]
# 14    Afghanistan  2001  133.8 [122.6-146.8]
# 15    Afghanistan  2000  137.0 [125.6-150.1]
# 16    Afghanistan  1999  139.9 [128.3-153.1]
# 17    Afghanistan  1998  142.6 [130.7-155.9]
# 18    Afghanistan  1997  145.5 [133.1-159.0]
# 19    Afghanistan  1996  148.6 [135.6-162.7]
# 20    Afghanistan  1995  152.3 [138.3-167.2]
# 21    Afghanistan  1994  156.8 [142.0-172.4]
# 22    Afghanistan  1993  162.0 [146.5-178.5]
# 23    Afghanistan  1992  167.8 [151.7-185.3]
# 24    Afghanistan  1991  174.2 [157.2-192.8]
# 25    Afghanistan  1990  181.0 [163.1-201.7]
# 26        Albania  2015      14.0 [7.9-24.9]
# 27        Albania  2014      14.4 [8.4-24.9]
# 28        Albania  2013      14.9 [8.9-24.9]
# 29        Albania  2012      15.5 [9.6-25.0]
# ...           ...   ...                  ...
# 5014       Zambia  1993  187.5 [176.2-199.2]
# 5015       Zambia  1992  189.4 [178.1-201.0]
# 5016       Zambia  1991  190.3 [178.9-202.2]
# 5017       Zambia  1990  190.6 [179.3-202.4]
# 5018     Zimbabwe  2015     70.7 [50.9-97.6]
# 5019     Zimbabwe  2014     72.3 [54.6-96.3]
# 5020     Zimbabwe  2013     74.5 [59.1-95.1]
# 5021     Zimbabwe  2012     78.5 [65.2-96.2]
# 5022     Zimbabwe  2011    85.6 [73.8-100.7]
# 5023     Zimbabwe  2010    89.5 [79.0-102.2]
# 5024     Zimbabwe  2009    92.9 [83.1-104.1]
# 5025     Zimbabwe  2008    95.4 [86.2-106.0]
# 5026     Zimbabwe  2007    98.0 [89.0-108.4]
# 5027     Zimbabwe  2006   100.0 [91.0-110.2]
# 5028     Zimbabwe  2005   101.9 [92.5-112.0]
# 5029     Zimbabwe  2004   103.0 [93.4-113.4]
# 5030     Zimbabwe  2003   104.0 [94.2-114.3]
# 5031     Zimbabwe  2002   105.1 [95.1-115.3]
# 5032     Zimbabwe  2001   105.6 [95.7-115.8]
# 5033     Zimbabwe  2000   105.8 [96.3-115.8]
# 5034     Zimbabwe  1999   105.2 [96.0-114.7]
# 5035     Zimbabwe  1998   103.9 [95.2-113.0]
# 5036     Zimbabwe  1997   102.0 [93.7-110.7]
# 5037     Zimbabwe  1996    99.2 [91.3-107.5]
# 5038     Zimbabwe  1995    95.5 [88.1-103.3]
# 5039     Zimbabwe  1994     91.2 [84.3-98.6]
# 5040     Zimbabwe  1993     87.0 [80.4-93.9]
# 5041     Zimbabwe  1992     82.7 [76.3-89.3]
# 5042     Zimbabwe  1991     78.8 [72.5-85.2]
# 5043     Zimbabwe  1990     75.8 [69.7-82.0]
#
# [5044 rows x 3 columns]

# %%
mortality_rates.head(1)
# Out:
#        Country  Year      under5_m_rate
# 0  Afghanistan  2015  91.1 [69.6-118.8]

# %% [markdown]
# We have to slice data from under5_m_rate column because data is not in good form

# %%
# A helper function to pre process the data into a usable form
def slice_rates(rate):
    return float(rate.split(' ')[0])

# %%
#Applying function on datafrmaes single column
mortality_rates['under5_m_rate'] = mortality_rates['under5_m_rate'].apply(slice_rates)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
mortality_rates.head()
# Out:
#        Country  Year  under5_m_rate
# 0  Afghanistan  2015           91.1
# 1  Afghanistan  2014           93.9
# 2  Afghanistan  2013           96.7
# 3  Afghanistan  2012           99.5
# 4  Afghanistan  2011          102.3

# %%
mortality_rates.describe()
# Out:
#               Year  under5_m_rate
# count  5044.000000    5044.000000
# mean   2002.500000      52.237550
# std       7.500744      55.236709
# min    1990.000000       1.900000
# 25%    1996.000000      11.900000
# 50%    2002.500000      28.300000
# 75%    2009.000000      78.300000
# max    2015.000000     328.200000

# %%
mortality_rates[mortality_rates['Year'] == 1990].sort_values(by = 'under5_m_rate')[:5]
# Out:
#                 Country  Year  under5_m_rate
# 2235              Japan  1990            6.3
# 2001            Iceland  1990            6.4
# 1585            Finland  1990            6.7
# 4341             Sweden  1990            6.9
# 3613  Republic of Korea  1990            7.1

# %%
def yearly_data(year):
    """
    returns country wisemortality rate in ascending order
    for a given year
    """
    m_rates = mortality_rates[mortality_rates['Year'] == year].copy()
    # slicing for the given year
    m_rates.drop('Year',axis=1, inplace=True)
    #dropping the year column which is low irrelevant
    m_rates.set_index('Country',inplace=True)
    #setting the index to country for easier operations
    return m_rates.sort_values(by = 'under5_m_rate')
#returning the sorted data

# %%
mrates_1990=yearly_data(1990)

# %% [markdown]
#  5 Countries With The Best Mortality Rates in 1990

# %%
mrates_1990.head()
# Out:
#                    under5_m_rate
# Country
# Japan                        6.3
# Iceland                      6.4
# Finland                      6.7
# Sweden                       6.9
# Republic of Korea            7.1

# %% [markdown]
# 5 Countries With The Worst Mortality Rates in 1990

# %%
mrates_1990.tail()
# Out:
#               under5_m_rate
# Country
# South Sudan           253.2
# Mali                  254.4
# Liberia               255.0
# Sierra Leone          264.3
# Niger                 328.2

# %%
mrates_1990.plot()

# %% [markdown]
#     The graph shows the stark variation in mortality rates, there are countries with mortality rates under 50 or even under 10, and then there are the ones with a rate over 200 and even 300
#
# The line plot is a good visualisation for bringing out the disparity in mortality rates, but let us plot a bar graph of a select few countries to get a more clear view

# %% [markdown]
# ###### If we want to see the data for all over the world :-

# %%
mrates_1990.iloc[::10, :].plot.bar()

# %% [markdown]
# ###### Problem 2 :-
#   Graph the under-five mortality rates as above, but for 2015 ?

# %%
mrates_2015=yearly_data(2015)

# %% [markdown]
# 5 countires with the best mortality rate in 2015

# %%
mrates_2015.head()
# Out:
#             under5_m_rate
# Country
# Luxembourg            1.9
# Iceland               2.0
# Finland               2.3
# Slovenia              2.6
# Norway                2.6

# %% [markdown]
# 5 countires with the Worst mortality rate in 2015

# %%
mrates_2015[-5:]
# Out:
#                           under5_m_rate
# Country
# Sierra Leone                      120.4
# Central African Republic          130.1
# Somalia                           136.8
# Chad                              138.7
# Angola                            156.9

# %%
mrates_2015.plot()

# %% [markdown]
#     The stark variation between mortality rates across countries observed in 1990 is still prevelant in 2015 but this time the peak has reduced from over 300 to less than 150!
#
#     Let us examine this disparity a little more clearly for a select few countries in a bar graph

# %%
mrates_2015.iloc[::10, : ].plot.bar()

# %% [markdown]
# ###### Next Problem :-
#
# choose three representative countries in different areas of the world, then create a line graph showing the trends in under-five mortality in those countries over the years from 1990 to 2015.

# %%
def country_data(country):
    """
    returns year wise mortality rate for a particular rate for a particular country
    """
    country_df = mortality_rates[mortality_rates['Country']
                                == country].copy()
    #slicing data for the particular country
    country_df.drop('Country',axis = 1, inplace=True)
    #dropping the country column which is now irrelevant
    country_df.set_index('Year', inplace = True)
    #setting the index as year to facilitate easier merge operations
    country_df.columns = [country]
    #setting the name of the column to the country name
    return country_df

# %% [markdown]
# For this problem, let us choose 3 countries from 3 different parts of the world :
#
#  1.   Sweden : One of the most developed countries in the world from Scandivania.
#  2.   Mali : One of the most underdeveloped countires in the world from Africa.
#  3.   India : A country that is devloping very fast from Asia.

# %%
country_data
# Out:
# <function __main__.country_data(country)>

# %%
sweden_data = country_data('Sweden')
mali_data = country_data('Mali')
india_data = country_data('India')

# %%
sweden_data
# Out:
#       Sweden
# Year
# 2015     3.0
# 2014     3.0
# 2013     3.0
# 2012     3.0
# 2011     3.0
# 2010     3.1
# 2009     3.1
# 2008     3.2
# 2007     3.3
# 2006     3.4
# 2005     3.6
# 2004     3.7
# 2003     3.9
# 2002     4.0
# 2001     4.1
# 2000     4.1
# 1999     4.1
# 1998     4.2
# 1997     4.3
# 1996     4.5
# 1995     4.8
# 1994     5.2
# 1993     5.7
# 1992     6.1
# 1991     6.6
# 1990     6.9

# %%
india_data
# Out:
#       India
# Year
# 2015   47.7
# 2014   49.8
# 2013   52.1
# 2012   54.5
# 2011   57.2
# 2010   59.9
# 2009   62.7
# 2008   65.6
# 2007   68.5
# 2006   71.5
# 2005   74.6
# 2004   77.7
# 2003   81.0
# 2002   84.3
# 2001   87.7
# 2000   91.2
# 1999   94.8
# 1998   98.3
# 1997  101.9
# 1996  105.3
# 1995  108.7
# 1994  112.1
# 1993  115.4
# 1992  118.8
# 1991  122.2
# 1990  125.8

# %%
mali_data
# Out:
#        Mali
# Year
# 2015  114.7
# 2014  118.3
# 2013  122.7
# 2012  127.0
# 2011  131.7
# 2010  136.6
# 2009  142.0
# 2008  148.3
# 2007  155.1
# 2006  162.9
# 2005  171.8
# 2004  181.7
# 2003  191.8
# 2002  201.8
# 2001  211.2
# 2000  219.6
# 1999  226.4
# 1998  231.7
# 1997  235.3
# 1996  237.9
# 1995  240.0
# 1994  242.0
# 1993  243.9
# 1992  246.6
# 1991  250.0
# 1990  254.4

# %%
# Merging the data for the three countries into a single dataframe;
india_sweden = india_data.merge(sweden_data, left_index = True,
                               right_index=True)
three_countries = india_sweden.merge(mali_data,left_index=True,
                                    right_index=True)

# %%
three_countries.head()
# Out:
#       India  Sweden   Mali
# Year
# 2015   47.7     3.0  114.7
# 2014   49.8     3.0  118.3
# 2013   52.1     3.0  122.7
# 2012   54.5     3.0  127.0
# 2011   57.2     3.0  131.7

# %% [markdown]
# Now that we have our data in a suitable format, let us visualise it!

# %%
three_countries.plot()

# %% [markdown]
# Observations
#
#     Mali is the worst hit country when it comes to under 5 mortality rate, at the same time though, it is making significant improvements
#     India has been showing a linear improvement
#     Sweden already had a really good record, now it is touching close to 0 'under 5 mortality rates'

# %% [markdown]
# ###### Next Problem
#
# for those same three countries, graph the reduction in under-five mortality rates over the 1990/2015 period - that is, the 1990 rate divided by the 2015 rate.

# %%
three_countries.pct_change().plot()

# %% [markdown]
# Observations :
#
#   * India has been showing a very consistent improvement
#   * Mali's rate of improvement peaked near the turn of the century, since than it has been on a decline
#   * Sweden already has a very low under 5 mortality rate, which explains the haphazard pattern in it's rate   of  improvement over time

# %% [markdown]
# We have observed the trend for different countries of the world, how do we analyse our progress on the whole, together as a planet

# %%
world_mortality_rates = pd.Series()

for year,group in mortality_rates.groupby('Year'):
    world_mortality_rates = world_mortality_rates.append(pd.Series(group['under5_m_rate'].mean(),
                     index=[year]))

# %%
world_mortality_rates.head()
# Out:
# 1990    72.543299
# 1991    71.063402
# 1992    69.684021
# 1993    68.422680
# 1994    67.624742
# dtype: float64

# %%
world_mortality_rates.plot()

# %% [markdown]
# We now have year wise average under 5 mortality rate for the entire world, let us visualise it

# %% [markdown]
# Although these averages aren't absolute given the difference in populations of different countries, these values are really good indicators of our progress on this parameter!

# %%
world_mortality_rates.pct_change().plot()

# %% [markdown]
# ###### Conclusions :-
#
#    * The average rate of under 5 mortality rates for all the countries of the world aggregated together has been falling very consistently from 1990 to 2015
#    * We can be very hopeful about acheiving this SDG (Sustainable Development Goal) by 2030

# %% [markdown]
# #### Processing the country data

# %%
countries=pd.read_csv('countries.csv')

# %%
countries.head()
# Out:
#   DimensionCode DimensionMemberCode DisplayString  DisplaySequence  URL   DS  \
# 0       COUNTRY                 AFG   Afghanistan               10  NaN  AFG
# 1       COUNTRY                 ALB       Albania               20  NaN   AL
# 2       COUNTRY                 DZA       Algeria               30  NaN   DZ
# 3       COUNTRY                 AND       Andorra               40  NaN  AND
# 4       COUNTRY                 AGO        Angola               50  NaN  NaN
#
#   FIPS GEOMETRY  IOC  ISO                 ...                   SHORTNAMEFR  \
# 0   AF      AFG  AFG  AFG                 ...                   Afghanistan
# 1   AL      ALB  ALB  ALB                 ...                       Albanie
# 2   AG      DZA  ALG  DZA                 ...                       Algérie
# 3   AN      AND  AND  AND                 ...                       Andorre
# 4   AO      AGO  ANG  AGO                 ...                        Angola
#
#    WHO WHOLEGALSTATUS             WHO_REGION WHO_REGION_CODE  WMO  \
# 0  AFG              M  Eastern Mediterranean             EMR   AF
# 1  ALB              M                 Europe             EUR   AB
# 2  ALG              M                 Africa             AFR   AL
# 3  AND              M                 Europe             EUR  NaN
# 4  ANG              M                 Africa             AFR   AN
#
#   WORLD_BANK_INCOME_GROUP WORLD_BANK_INCOME_GROUP_CODE  \
# 0              Low-income                        WB_LI
# 1     Upper-middle-income                       WB_UMI
# 2     Upper-middle-income                       WB_UMI
# 3             High-income                        WB_HI
# 4     Upper-middle-income                       WB_UMI
#
#   WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR  \
# 0                                     2015.0
# 1                                     2015.0
# 2                                     2015.0
# 3                                     2015.0
# 4                                     2015.0
#
#   WORLD_BANK_INCOME_GROUP_RELEASE_DATE
# 0                               2016.0
# 1                               2016.0
# 2                               2016.0
# 3                               2016.0
# 4                               2016.0
#
# [5 rows x 27 columns]

# %% [markdown]
# This dataframe contains a lot of information, we only need some of it, let us remove the excess.

# %%
# Removing the rows where 'SHORTNAMEFR' is null

countries.dropna(subset = ['SHORTNAMEFR'], inplace=True)

# %%
# slicing the columns that we need
#We use 'DisplayString' instead of 'SHORTNAMEFR' this time because it has the right spellings for the countries
countries = countries[['DisplayString','WHO_REGION',
                      'WORLD_BANK_INCOME_GROUP']]

# %%
countries.head()
# Out:
#   DisplayString             WHO_REGION WORLD_BANK_INCOME_GROUP
# 0   Afghanistan  Eastern Mediterranean              Low-income
# 1       Albania                 Europe     Upper-middle-income
# 2       Algeria                 Africa     Upper-middle-income
# 3       Andorra                 Europe             High-income
# 4        Angola                 Africa     Upper-middle-income

# %% [markdown]
# Now our data is ready to be merged with under 5 mortality rates data

# %%
# dfname.to_csv('dfname.csv',index=False)
mortality_rates = pd.read_csv('mortality_processed.csv')
meta_data = mortality_rates.merge(countries,left_on='Country',right_on='DisplayString')
meta_data.drop(['DisplayString','Country'],axis=1, inplace=True)
#dropping the unnecessary columns

# %%
meta_data.head()
# Out:
#    Year  under5_m_rate             WHO_REGION WORLD_BANK_INCOME_GROUP
# 0  2016           70.4  Eastern Mediterranean              Low-income
# 1  2015           73.2  Eastern Mediterranean              Low-income
# 2  2014           76.1  Eastern Mediterranean              Low-income
# 3  2013           79.3  Eastern Mediterranean              Low-income
# 4  2012           82.8  Eastern Mediterranean              Low-income

# %% [markdown]
# ###### Now we have the data in the right form, let us go ahead and analyze some trends

# %% [markdown]
# ### Regional Trends

# %%
# Creating the empty dataframe that shall store
# average performance of different regions
regions = meta_data.WHO_REGION.unique()
years=meta_data.Year.unique()
regional_trends = pd.DataFrame(columns = regions, index=years)
regional_trends.head()
# Out:
#      Eastern Mediterranean Europe Africa Americas Western Pacific  \
# 2016                   NaN    NaN    NaN      NaN             NaN
# 2015                   NaN    NaN    NaN      NaN             NaN
# 2014                   NaN    NaN    NaN      NaN             NaN
# 2013                   NaN    NaN    NaN      NaN             NaN
# 2012                   NaN    NaN    NaN      NaN             NaN
#
#      South-East Asia
# 2016             NaN
# 2015             NaN
# 2014             NaN
# 2013             NaN
# 2012             NaN

# %%
# Filling the regional trends dataframe year wise and region wise
for name, group in meta_data.groupby(['WHO_REGION', 'Year']):
    region, year = name
    #print(group)
    
    regional_trends.loc[year,region] = group['under5_m_rate'].mean()
regional_trends.head()
# Out:
#      Eastern Mediterranean   Europe   Africa Americas Western Pacific  \
# 2016               32.7619  8.20943  68.0064  17.8943            22.2
# 2015               33.6857  8.51509  70.6723    18.38         22.8815
# 2014               34.6524  8.83962  73.4745  18.8686         23.5407
# 2013               35.6524  9.19434  76.5511    19.36         24.2185
# 2012               36.7143  9.57925  79.8723  19.8514         24.9074
#
#      South-East Asia
# 2016         29.1909
# 2015         30.4636
# 2014         31.8909
# 2013         33.4455
# 2012         35.0909

# %%
regional_trends.plot(title = 'region wise mortality rates from 1990 to 2015')

# %% [markdown]
#    * Not surprisngly, the western countries seam to be doing much better then their eastern counterparts on this demographic
#    * Let us see which regions are progressing at a rate faster than others

# %%
regional_trends.pct_change().plot()

# %%
regional_trends.mean
# Out:
# <bound method DataFrame.mean of      Eastern Mediterranean   Europe   Africa Americas Western Pacific  \
# 2016               32.7619  8.20943  68.0064  17.8943            22.2
# 2015               33.6857  8.51509  70.6723    18.38         22.8815
# 2014               34.6524  8.83962  73.4745  18.8686         23.5407
# 2013               35.6524  9.19434  76.5511    19.36         24.2185
# 2012               36.7143  9.57925  79.8723  19.8514         24.9074
# 2011               37.7857  10.0094  83.4426  20.3657            25.6
# 2010               38.8524  10.4679  87.5085  24.5914         26.2926
# 2009               40.0905  10.9736  91.7723     21.5         27.2333
# 2008               41.4619  11.5189  96.1872  22.1229         27.7556
# 2007               42.8476  12.1132  100.574  22.7886         28.4852
# 2006                  44.2  12.7566  105.251  23.4657         29.2407
# 2005               45.5524  13.4472  110.198  24.2286         30.0296
# 2004               46.9333  14.1774  115.217  25.0086         30.9185
# 2003               48.3381  14.9585  120.211  25.8486         31.8963
# 2002               49.8143  15.7887  125.147  26.7286              33
# 2001               51.3476  16.6604  129.936  27.6886         34.1963
# 2000               52.9476  17.5642  134.404  28.7229         35.4407
# 1999               54.6048  18.4698  138.236  30.0029         36.6593
# 1998               56.2714  19.3604  142.057  31.7771         37.8037
# 1997               57.9952  20.2113   144.27  32.3229         39.0407
# 1996               59.7571  21.0189  145.928  33.6657         39.8852
# 1995               61.5524  21.7962  148.979  35.0429         40.9074
# 1994               63.4095  22.4491   151.37    36.48          41.937
# 1993               65.3667  23.0075  150.853  37.9657         43.0222
# 1992               67.4476  23.3962  152.085     39.5         44.1889
# 1991               69.8524  23.7415  153.643  41.0971         45.4481
# 1990               72.1571  24.2642   155.36  42.7371          46.763
#
#      South-East Asia
# 2016         29.1909
# 2015         30.4636
# 2014         31.8909
# 2013         33.4455
# 2012         35.0909
# 2011         36.9182
# 2010         38.8182
# 2009         40.8636
# 2008         44.7455
# 2007         45.1636
# 2006         47.4818
# 2005         49.9818
# 2004         54.8545
# 2003         55.7818
# 2002            59.1
# 2001         62.7273
# 2000         66.5455
# 1999         70.4273
# 1998         74.2636
# 1997         77.9636
# 1996         81.4545
# 1995         84.7455
# 1994            87.9
# 1993              91
# 1992         94.1364
# 1991         97.3909
# 1990         100.836  >

# %%
#visualising under 5 mortality rates at 10 year
#intervals for different regions
regional_trends.transpose().iloc[:,::10].plot.bar(title = 'decadal changes in mortality rates across regions')

# %% [markdown]
# All regions have been making making progress, the challenge for Africa has been much more bigger but it has been making improvements at equally big scales!

# %%
# Creating a empty dataframe that shall store average performance of different income groups
income = meta_data.WORLD_BANK_INCOME_GROUP.unique()
years=meta_data.Year.unique()
income_trends = pd.DataFrame(columns =income, index=years)
income_trends.head()
# Out:
#      Low-income Upper-middle-income High-income Not classified  \
# 2016        NaN                 NaN         NaN            NaN
# 2015        NaN                 NaN         NaN            NaN
# 2014        NaN                 NaN         NaN            NaN
# 2013        NaN                 NaN         NaN            NaN
# 2012        NaN                 NaN         NaN            NaN
#
#      Lower-middle-income
# 2016                 NaN
# 2015                 NaN
# 2014                 NaN
# 2013                 NaN
# 2012                 NaN

# %%
# Filling the dataframe year wise and income group wise
for name, group in meta_data.groupby(['WORLD_BANK_INCOME_GROUP', 'Year']):
    income, year = name
    #print(group)
    
    income_trends.loc[year,income] = group['under5_m_rate'].mean()
income_trends.head()
# Out:
#      Low-income Upper-middle-income High-income Not classified  \
# 2016    73.0625              21.087     6.15263           11.1
# 2015      75.95             21.8204     6.30526           11.6
# 2014     79.125             22.5093     6.45263           12.1
# 2013    82.5875             23.2556     6.62105           12.7
# 2012    86.3188             24.0926     6.80175           13.3
#
#      Lower-middle-income
# 2016              40.554
# 2015              41.936
# 2014              43.378
# 2013              44.892
# 2012              46.436

# %%
income_trends.plot()

# %% [markdown]
#    * This is a very surprising trend! It shows that under 5 mortality rate is directly proportional to the income of the indivisuals!
#    * Let us examine this situation for the present year

# %%
# Examining the latest situation
income_trends.loc[2016].sort_values().plot.bar(title = 'Under 5 mortality rates in 2016')

# %% [markdown]
# Since there is a strong correlation between incomes and mortality rates, focussing efforts on economic development should also help acheive this sustainable development goal!
